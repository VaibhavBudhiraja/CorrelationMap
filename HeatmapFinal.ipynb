# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
print("Welcome setup is complete")
# Out:
# Welcome setup is complete

# %% [markdown]
# ### Reading the data from excel or CSV files

# %%
df = pd.read_csv('Hdpe.csv')    # File loading for excel and csv 
print(df)
# Out:
#    Unnamed: 0  Density  Carbonyl Index  Ester Index  Vinyl Index  \
# 0     HDPE 0h   0.9474           0.132        0.059        0.065
# 1   HDPE 250h   0.9498           0.234        0.087        0.084
# 2   HDPE 500h   0.9793           0.531        0.156        0.115
# 3   HDPE 750h   0.9869           0.553        0.217        0.141
# 4  HDPE 1000h   1.0048           0.736        0.178        0.115
#
#    Hydroxy Index  Internal Bond Index  Tos   T50%  T90%   Tp  Crystallinity   \
# 0          0.038                0.111   492   507   523  497              74
# 1          0.072                0.108   494   509   522  514              65
# 2          0.098                0.143   487   507   522  511              64
# 3          0.121                0.168   486   507   523  511              64
# 4          0.081                0.127   486   508   524  514              68
#
#    Tm   SBET
# 0  137   0.50
# 1  136    NaN
# 2  131    NaN
# 3  131    NaN
# 4  129   0.75

# %% [markdown]
# ### Droping the unused coloumn and rows

# %%
df.drop(columns=['Unnamed: 0'], inplace= True)
df.head()
# Out:
#    Density  Carbonyl Index  Ester Index  Vinyl Index  Hydroxy Index  \
# 0   0.9474           0.132        0.059        0.065          0.038
# 1   0.9498           0.234        0.087        0.084          0.072
# 2   0.9793           0.531        0.156        0.115          0.098
# 3   0.9869           0.553        0.217        0.141          0.121
# 4   1.0048           0.736        0.178        0.115          0.081
#
#    Internal Bond Index  Tos   T50%  T90%   Tp  Crystallinity   Tm   SBET
# 0                0.111   492   507   523  497              74  137   0.50
# 1                0.108   494   509   522  514              65  136    NaN
# 2                0.143   487   507   522  511              64  131    NaN
# 3                0.168   486   507   523  511              64  131    NaN
# 4                0.127   486   508   524  514              68  129   0.75

# %% [markdown]
# ### Basic correlation  plot

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# ### Well decorated corelation plot using heatmap in seaborn

# %%
mat = np.triu(df.corr())   # upper triangular matrix
#plt.figure(figsize=(9,9))
sns.heatmap(df.corr(), annot=True, linewidth=.7, cmap='bwr', vmin=-1, vmax=1, mask=mat, square=True,  fmt=".1f")
#plt.show()
# Out:
# <Axes: >

# %%
mat1 = np.tril(df.corr())   # upper triangular matrix
#plt.figure(figsize=(9,9))
sns.heatmap(df.corr(), annot=True, linewidth=.7, cmap='bwr', vmin=-1, vmax=1, mask=mat1, square=True,  fmt=".1f")
#plt.show()
# Out:
# <Axes: >
